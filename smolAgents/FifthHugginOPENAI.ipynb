# %% [markdown]
# ## Agents AI - Using openAI token
#
# * py310

# %%
## !pip install smolagents
## !pip install datasets
## !pip install langchain
## !pip install langchain_community

## !pip -q install smolagents
## !pip -q install litellm

# %%
'''

export OPENAI_API_KEY="your_api_key_here"

restart "jupyter notebook" 

echo $OPENAI_API_KEY

openai.api_key = os.getenv("OPENAI_API_KEY")


'''
# Out:
# '\n\nexport OPENAI_API_KEY="your_api_key_here"\n\nrestart "jupyter notebook" \n\necho $OPENAI_API_KEY\n\nopenai.api_key = os.getenv("OPENAI_API_KEY")\n\n\n'

# %%
import os

# %%
## print( os.getenv('HF_TOKEN') )

os.environ['HF_TOKEN'] =  os.getenv('HF_TOKEN')

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel

# %%
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, LiteLLMModel

## model = LiteLLMModel(model_id="gpt-4o-mini")

model = LiteLLMModel(model_id="gpt-4o-mini", api_key = os.getenv("OPENAI_API_KEY"))

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model, additional_authorized_imports=[ 'math'])
# Out:
# /Users/user/opt/anaconda3/envs/py310_agentsAI/lib/python3.10/site-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)

# %%
agent.run("Calculate how long does it take to drive from New orleans to Baton Rouge?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Calculate how long does it take to drive from New orleans to Baton Rouge?                                       │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4o-mini ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   driving_time = web_search(query="New Orleans to Baton Rouge driving time")
#   print(driving_time)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'driving_time = web_search(query="New Orleans to Baton Rouge driving time")' due to:
# DuckDuckGoSearchException: https://html.duckduckgo.com/html 202 Ratelimit
# [Step 1: Duration 4.77 seconds| Input tokens: 1,998 | Output tokens: 87]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   driving_time_alternate = web_search(query="how long does it take to drive from New Orleans to Baton Rouge")
#   print(driving_time_alternate)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'driving_time_alternate = web_search(query="how long does it take to drive from New
# Orleans to Baton Rouge")' due to: DuckDuckGoSearchException: https://html.duckduckgo.com/html 202 Ratelimit
# [Step 2: Duration 4.70 seconds| Input tokens: 4,231 | Output tokens: 191]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   distance_miles = 80
#   average_speed_mph = 60
#   driving_time_hours = distance_miles / average_speed_mph
#   print(driving_time_hours)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 1.3333333333333333
#
# Out: None
# [Step 3: Duration 2.09 seconds| Input tokens: 6,734 | Output tokens: 308]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Approximately 1 hour and 20 minutes")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Approximately 1 hour and 20 minutes
# [Step 4: Duration 22.84 seconds| Input tokens: 9,453 | Output tokens: 373]
# 'Approximately 1 hour and 20 minutes'

# %%
agent.run("What's the weather like in Paris tomorrow? ")
